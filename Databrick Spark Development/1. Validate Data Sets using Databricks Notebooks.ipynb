# %%
# %fs ls /FileStore/tables/public/retail_db
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls /FileStore/tables/public/retail_db/orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/public/retail_db/orders/part_00000</td><td>part_00000</td><td>3068827</td><td>1665305541000</td></tr></tbody></table></div>

# %%
# %fs ls /public/retail_db_json
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls /public/retail_db_json/orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/public/retail_db_json/orders/part-r-00000-990f5773-9005-49ba-b670-631286032674</td><td>part-r-00000-990f5773-9005-49ba-b670-631286032674</td><td>7477339</td></tr></tbody></table></div>

# %%
dbutils.fs.ls('/public/retail_db_json/orders')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: [FileInfo(path=&#39;dbfs:/public/retail_db_json/orders/part-r-00000-990f5773-9005-49ba-b670-631286032674&#39;, name=&#39;part-r-00000-990f5773-9005-49ba-b670-631286032674&#39;, size=7477339)]</div>

# %%
for file_details in dbutils.fs.ls('/public/retail_db_json'):
  print(file_details)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">FileInfo(path=&#39;dbfs:/public/retail_db_json/categories/&#39;, name=&#39;categories/&#39;, size=0)
# FileInfo(path=&#39;dbfs:/public/retail_db_json/create_db_tables_pg.sql&#39;, name=&#39;create_db_tables_pg.sql&#39;, size=1748)
# FileInfo(path=&#39;dbfs:/public/retail_db_json/customers/&#39;, name=&#39;customers/&#39;, size=0)
# FileInfo(path=&#39;dbfs:/public/retail_db_json/departments/&#39;, name=&#39;departments/&#39;, size=0)
# FileInfo(path=&#39;dbfs:/public/retail_db_json/order_items/&#39;, name=&#39;order_items/&#39;, size=0)
# FileInfo(path=&#39;dbfs:/public/retail_db_json/orders/&#39;, name=&#39;orders/&#39;, size=0)
# ...

# %%
for file_details in dbutils.fs.ls('/public/retail_db_json'):
  print(file_details.path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/public/retail_db_json/categories/
# dbfs:/public/retail_db_json/create_db_tables_pg.sql
# dbfs:/public/retail_db_json/customers/
# dbfs:/public/retail_db_json/departments/
# dbfs:/public/retail_db_json/order_items/
# dbfs:/public/retail_db_json/orders/
# dbfs:/public/retail_db_json/products/
# </div>
