# %% [markdown]
# <i18n value="46a8383a-807d-42a9-9bdc-09a34e0b7bd0"/>
#
#
# # Exploring the Results of a DLT Pipeline
#
# This notebook explores the execution results of a DLT pipeline.

# %%
# %run ../../Includes/Classroom-Setup-08.1.3
# Out:
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Skipping install of existing datasets to "dbfs:/mnt/dbacademy-datasets/data-engineering-with-databricks/v02"
#
# Validating the locally installed datasets:
# | listing local files...(7 seconds)
# | completed (7 seconds total)
#
# Creating & using the schema "munirsheikhcloudseekho_0lj9_da_dewd_dlt_demo_81"...(0 seconds)
# Predefined tables in "munirsheikhcloudseekho_0lj9_da_dewd_dlt_demo_81":
# | -none-
#
# Predefined paths variables:
# | DA.paths.working_dir:      dbfs:/mnt/dbacademy-users/munirsheikhcloudseekho@gmail.com/data-engineering-with-databricks/dlt_demo_81
# | DA.paths.user_db:          dbfs:/mnt/dbacademy-users/munirsheikhcloudseekho@gmail.com/data-engineering-with-databricks/dlt_demo_81/database.db
# | DA.paths.datasets:         dbfs:/mnt/dbacademy-datasets/data-engineering-with-databricks/v02
# ...

# %%
files = dbutils.fs.ls(DA.paths.storage_location)
display(files)
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# <command-4094000743659737> in <cell line: 1>()
# ----> 1 files = dbutils.fs.ls(DA.paths.storage_location)
#       2 display(files)
#
# /databricks/python_shell/dbruntime/dbutils.py in f_with_exception_handling(*args, **kwargs)
#     360                     exc.__context__ = None
#     361                     exc.__cause__ = None
# --> 362                     raise exc
#     363
#     364             return f_with_exception_handling
#
# ExecutionError: An error occurred while calling o515.ls.
# : java.io.FileNotFoundException: /mnt/dbacademy-users/munirsheikhcloudseekho@gmail.com/data-engineering-with-databricks/dlt_demo_81/storage
# 	at com.databricks.backend.daemon.data.client.DbfsClient.send0(DbfsClient.scala:121)
# 	at com.databricks.backend.daemon.data.client.DbfsClient.sendIdempotent(DbfsClient.scala:69)
# ...

# %% [markdown]
# <i18n value="4b109d6f-b0d4-4ded-ac54-a12f722599a9"/>
#
#
# The **`system`** directory captures events associated with the pipeline.

# %%
files = dbutils.fs.ls(f"{DA.paths.storage_location}/system/events")
display(files)

# %% [markdown]
# <i18n value="fd83d9bb-db62-456a-8a51-33e8680c0d47"/>
#
#
# These event logs are stored as a Delta table. Let's query the table.

# %%
# %sql
SELECT * FROM delta.`${da.paths.storage_location}/system/events`

# %% [markdown]
# <i18n value="b0c12205-fc10-4a63-a73e-d5cded65ef51"/>
#
#
# Let's view the contents of the *tables* directory.

# %%
files = dbutils.fs.ls(f"{DA.paths.storage_location}/tables")
display(files)

# %% [markdown]
# <i18n value="e5072a3f-3a1f-4e4d-89fa-bda3926cb6ba"/>
#
#
# Let's query the gold table.

# %%
# %sql
SELECT * FROM ${da.schema_name}.sales_order_in_la

# %% [markdown]
# <i18n value="69333106-f421-45f0-a846-1c3d4fc8ddcb"/>
#
#
# Run the following cell to delete the tables and files associated with this lesson.

# %%
DA.cleanup()
