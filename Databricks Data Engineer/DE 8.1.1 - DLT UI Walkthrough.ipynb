# %% [markdown]
# -sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# <i18n value="1fb32f72-2ccc-4206-98d9-907287fc3262"/>
#
#
# # Using the Delta Live Tables UI
#
# This demo will explore the DLT UI.
#
#
# ## Learning Objectives
# By the end of this lesson, you should be able to:
# * Deploy a DLT pipeline
# * Explore the resultant DAG
# * Execute an update of the pipeline
# * Look at metrics

# %% [markdown]
# <i18n value="c950ed75-9a93-4340-a82c-e00505222d15"/>
#
#
# ## Run Setup
#
# The following cell is configured to reset this demo.

# %%
# %run ../../Includes/Classroom-Setup-08.1.1
# Out:
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Skipping install of existing datasets to "dbfs:/mnt/dbacademy-datasets/data-engineering-with-databricks/v02"
#
# Validating the locally installed datasets:
# | listing local files...(8 seconds)
# | completed (8 seconds total)
#
# Creating & using the schema "munirsheikhcloudseekho_0lj9_da_dewd_dlt_demo_81"...(0 seconds)
# Predefined tables in "munirsheikhcloudseekho_0lj9_da_dewd_dlt_demo_81":
# | -none-
#
# Predefined paths variables:
# | DA.paths.working_dir:      dbfs:/mnt/dbacademy-users/munirsheikhcloudseekho@gmail.com/data-engineering-with-databricks/dlt_demo_81
# | DA.paths.user_db:          dbfs:/mnt/dbacademy-users/munirsheikhcloudseekho@gmail.com/data-engineering-with-databricks/dlt_demo_81/database.db
# | DA.paths.datasets:         dbfs:/mnt/dbacademy-datasets/data-engineering-with-databricks/v02
# | DA.paths.checkpoints:      dbfs:/mnt/dbacademy-users/munirsheikhcloudseekho@gmail.com/data-engineering-with-databricks/dlt_demo_81/_checkpoints
# | DA.paths.stream_path:      dbfs:/mnt/dbacademy-users/munirsheikhcloudseekho@gmail.com/data-engineering-with-databricks/dlt_demo_81/stream
# | DA.paths.storage_location: dbfs:/mnt/dbacademy-users/munirsheikhcloudseekho@gmail.com/data-engineering-with-databricks/dlt_demo_81/storage
#
# Setup completed (9 seconds)

# %% [markdown]
# <i18n value="0a719ade-b4b5-49b5-89bf-8fc2b0b7d63c"/>
#
#
# Execute the following cell to print out values that will be used during the following configuration steps.

# %%
DA.print_pipeline_config()
# Out:
# <table style="width:100%">
#     <tr>
#         <td style="white-space:nowrap; width:1em">Pipeline Name:</td>
#         <td><input type="text" value="DLT-Demo-81-munirsheikhcloudseekho@gmail.com" style="width:100%"></td></tr>
#     <tr>
#         <td style="white-space:nowrap; width:1em">Target:</td>
#         <td><input type="text" value="munirsheikhcloudseekho_0lj9_da_dewd_dlt_demo_81" style="width:100%"></td></tr>
#     <tr>
#         <td style="white-space:nowrap; width:1em">Storage Location:</td>
#         <td><input type="text" value="dbfs:/mnt/dbacademy-users/munirsheikhcloudseekho@gmail.com/data-engineering-with-databricks/dlt_demo_81/storage" style="width:100%"></td></tr>
#     <tr>
#         <td style="white-space:nowrap; width:1em">Notebook Path:</td>
#         <td><input type="text" value="/Users/munirsheikhcloudseekho@gmail.com/data-engineering-with-databricks/data-engineering-with-databricks/Solutions/08 - Delta Live Tables/DE 8.1 - DLT/DE 8.1.2 - SQL for Delta Live Tables" style="width:100%"></td></tr>
#     <tr>
#         <td style="white-space:nowrap; width:1em">Datasets Path:</td>
#         <td><input type="text" value="dbfs:/mnt/dbacademy-datasets/data-engineering-with-databricks/v02" style="width:100%"></td></tr>
#     <tr>
#         <td style="white-space:nowrap; width:1em">Policy:</td>
#         <td><input type="text" value="DBAcademy DLT-Only Policy" style="width:100%"></td></tr>
#     </table>

# %% [markdown]
# <i18n value="71b010a3-80be-4909-9b44-6f68029f16c0"/>
#
#
# ## Create and Configure a Pipeline
#
# In this section you will create a pipeline using a notebook provided with the courseware. We'll explore the contents of the notebook in the following lesson.
#
# 1. Click the **Workflows** button on the sidebar.
# 1. Select the **Delta Live Tables** tab.
# 1. Click **Create Pipeline**.
# 1. Leave **Product Edition** as **Advanced**.
# 1. Fill in a **Pipeline Name** - because these names must be unique, we suggest using the **Pipeline Name** provided in the cell above.
# 1. For **Notebook Libraries**, use the navigator to locate and select the notebook specified above.
#    * Even though this document is a standard Databricks Notebook, the SQL syntax is specialized to DLT table declarations.
#    * We will be exploring the syntax in the exercise that follows.
# 1. Under **Configuration**, add two configuration parameters:
#    * Click **Add configuration**, set the "key" to **spark.master** and the "value" to **local[\*]**.
#    * Click **Add configuration**, set the "key" to **datasets_path** and the "value" to the value provided in the cell above.
# 1. In the **Target** field, enter the database name provided in the cell above.<br/>
# This should follow the pattern **`<name>_<hash>_dbacademy_dewd_dlt_demo_81`**
#    * This field is optional; if not specified, then tables will not be registered to a metastore, but will still be available in the DBFS. Refer to the <a href="https://docs.databricks.com/data-engineering/delta-live-tables/delta-live-tables-user-guide.html#publish-tables" target="_blank">documentation</a> for more information on this option.
# 1. In the **Storage location** field, enter the path provided in the cell above.
#    * This optional field allows the user to specify a location to store logs, tables, and other information related to pipeline execution.
#    * If not specified, DLT will automatically generate a directory.
# 1. For **Pipeline Mode**, select **Triggered**.
#    * This field specifies how the pipeline will be run.
#    * **Triggered** pipelines run once and then shut down until the next manual or scheduled update.
#    * **Continuous** pipelines run continuously, ingesting new data as it arrives. Choose the mode based on latency and cost requirements.
# 1. Uncheck the **Enable autoscaling** box.
# 1. Set the number of **`workers`** to **`0`** (zero).
#    * Along with the **spark.master** config above, this will create a **Single Node** clusters.
# 1. Check the **Use Photon Acceleration** box.
# 1. For **Channel**, select **Current**
# 1. For **Policy**, select the value provided in the cell above.
#
# The fields **Enable autoscaling**, **Min Workers** and **Max Workers** control the worker configuration for the underlying cluster processing the pipeline.
#
# Notice the DBU estimate provided, similar to that provided when configuring interactive clusters.
#
# Finally, click **Create**.

# %%
# ANSWER

# This function is provided for students who do not 
# want to work through the exercise of creating the pipeline.
DA.create_pipeline()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <command-4094000743659728> in <cell line: 5>()
#       3 # This function is provided for students who do not
#       4 # want to work through the exercise of creating the pipeline.
# ----> 5 DA.create_pipeline()
#
# <command-4094000743658862> in create_pipeline(self)
#       7     # We need to delete the existing pipline so that we can apply updates
#       8     # because some attributes are not mutable after creation.
# ----> 9     self.client.pipelines().delete_by_name(pipeline_name)
#      10
#      11     response = self.client.pipelines().create(
#
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-9b9b78d6-3c83-46db-8fa6-dc309225d573/lib/python3.9/site-packages/dbacademy/dbrest/pipelines.py in delete_by_name(self, pipeline_name)
#      48     def delete_by_name(self, pipeline_name):
#      49         import time
# ---> 50         pipeline = self.get_by_name(pipeline_name)
#      51         response = None if pipeline is None else self.delete_by_id(pipeline.get("pipeline_id"))
#      52
#
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-9b9b78d6-3c83-46db-8fa6-dc309225d573/lib/python3.9/site-packages/dbacademy/dbrest/pipelines.py in get_by_name(self, pipeline_name)
#      34
#      35     def get_by_name(self, pipeline_name):
# ---> 36         for pipeline in self.list():
#      37             if pipeline.get("name") == pipeline_name:
#      38                 pipeline_id = pipeline.get("pipeline_id")
#
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-9b9b78d6-3c83-46db-8fa6-dc309225d573/lib/python3.9/site-packages/dbacademy/dbrest/pipelines.py in list(self, max_results)
#      13     def list(self, max_results=100):
#      14         pipelines = []
# ---> 15         response = self.client.api("GET", f"{self.base_uri}?max_results={max_results}")
#      16
#      17         while True:
#
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-9b9b78d6-3c83-46db-8fa6-dc309225d573/lib/python3.9/site-packages/dbacademy/rest/common.py in api(self, _http_method, _endpoint_path, _data, _expected, _result_type, _base_url, **data)
#     189             # if self.verbose: print(json.dumps(data, indent=4))
#     190             response = self.session.request(_http_method, url, data=json.dumps(_data), timeout=timeout)
# --> 191         self._raise_for_status(response, _expected)
#     192         # TODO: Should we really return None on errors?  Kept for now for backwards compatibility.
#     193         if not (200 <= response.status_code < 300):
#
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-9b9b78d6-3c83-46db-8fa6-dc309225d573/lib/python3.9/site-packages/dbacademy/rest/common.py in _raise_for_status(response, expected)
#     282         if 400 <= response.status_code < 500:
#     283             e = DatabricksApiException(http_exception=e)
# --> 284         raise e
#     285
#     286     @deprecated(reason="Use ApiClient.api", action="error")
#
# HTTPError: 503 Server Error: Service Unavailable for url: https://community.cloud.databricks.com/api/2.0/pipelines?max_results=100
#  Response from server:
#  { 'error_code': 'TEMPORARILY_UNAVAILABLE',
#   'message': 'The service at /api/2.0/pipelines is temporarily unavailable. '
#              'Please try again later.'}

# %%
DA.validate_pipeline_config()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <command-4094000743659729> in <cell line: 1>()
# ----> 1 DA.validate_pipeline_config()
#
# <command-4094000743658863> in validate_pipeline_config(self)
#       7     pipeline_name, path = self.get_pipeline_config()
#       8
# ----> 9     pipeline = self.client.pipelines().get_by_name(pipeline_name)
#      10     assert pipeline is not None, f"The pipline named \"{pipeline_name}\" doesn't exist. Double check the spelling."
#      11
#
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-9b9b78d6-3c83-46db-8fa6-dc309225d573/lib/python3.9/site-packages/dbacademy/dbrest/pipelines.py in get_by_name(self, pipeline_name)
#      34
#      35     def get_by_name(self, pipeline_name):
# ---> 36         for pipeline in self.list():
#      37             if pipeline.get("name") == pipeline_name:
#      38                 pipeline_id = pipeline.get("pipeline_id")
#
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-9b9b78d6-3c83-46db-8fa6-dc309225d573/lib/python3.9/site-packages/dbacademy/dbrest/pipelines.py in list(self, max_results)
#      13     def list(self, max_results=100):
#      14         pipelines = []
# ---> 15         response = self.client.api("GET", f"{self.base_uri}?max_results={max_results}")
#      16
#      17         while True:
#
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-9b9b78d6-3c83-46db-8fa6-dc309225d573/lib/python3.9/site-packages/dbacademy/rest/common.py in api(self, _http_method, _endpoint_path, _data, _expected, _result_type, _base_url, **data)
#     189             # if self.verbose: print(json.dumps(data, indent=4))
#     190             response = self.session.request(_http_method, url, data=json.dumps(_data), timeout=timeout)
# --> 191         self._raise_for_status(response, _expected)
#     192         # TODO: Should we really return None on errors?  Kept for now for backwards compatibility.
#     193         if not (200 <= response.status_code < 300):
#
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-9b9b78d6-3c83-46db-8fa6-dc309225d573/lib/python3.9/site-packages/dbacademy/rest/common.py in _raise_for_status(response, expected)
#     282         if 400 <= response.status_code < 500:
#     283             e = DatabricksApiException(http_exception=e)
# --> 284         raise e
#     285
#     286     @deprecated(reason="Use ApiClient.api", action="error")
#
# HTTPError: 503 Server Error: Service Unavailable for url: https://community.cloud.databricks.com/api/2.0/pipelines?max_results=100
#  Response from server:
#  { 'error_code': 'TEMPORARILY_UNAVAILABLE',
#   'message': 'The service at /api/2.0/pipelines is temporarily unavailable. '
#              'Please try again later.'}

# %% [markdown]
# <i18n value="a7e4b2fc-83a1-4509-8269-9a4c5791de21"/>
#
#
# ## Run a Pipeline
#
# With a pipeline created, you will now run the pipeline.
#
# 1. Select **Development** to run the pipeline in development mode.
#   * Development mode provides for more expeditious iterative development by reusing the cluster (as opposed to creating a new cluster for each run) and disabling retries so that you can readily identify and fix errors.
#   * Refer to the <a href="https://docs.databricks.com/data-engineering/delta-live-tables/delta-live-tables-user-guide.html#optimize-execution" target="_blank">documentation</a> for more information on this feature.
# 2. Click **Start**.
#
# The initial run will take several minutes while a cluster is provisioned.
#
# Subsequent runs will be appreciably quicker.

# %%
# ANSWER

# This function is provided to start the pipeline and  
# block until it has completed, canceled or failed
DA.start_pipeline()

# %% [markdown]
# <i18n value="4b92f93e-7a7f-4169-a1d2-9df3ac440674"/>
#
#
# ## Exploring the DAG
#
# As the pipeline completes, the execution flow is graphed.
#
# Selecting the tables reviews the details.
#
# Select **sales_orders_cleaned**. Notice the results reported in the **Data Quality** section. Because this flow has data expectations declared, those metrics are tracked here. No records are dropped because the constraint is declared in a way that allows violating records to be included in the output. This will be covered in more details in the next exercise.

# %% [markdown]
# -sandbox
# &copy; 2022 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="https://help.databricks.com/">Support</a>
