# %%
# %run ../../Includes/Classroom-Setup-09.2.4L
# Out:
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Skipping install of existing datasets to "dbfs:/mnt/dbacademy-datasets/data-engineering-with-databricks/v02"
#
# Validating the locally installed datasets:
# | listing local files...(8 seconds)
# | completed (8 seconds total)
#
# Using the "default" schema.
#
# Predefined paths variables:
# | DA.paths.working_dir: dbfs:/mnt/dbacademy-users/munirsheikhcloudseekho@gmail.com/data-engineering-with-databricks/jobs_lab_92
# | DA.paths.user_db:     dbfs:/mnt/dbacademy-users/munirsheikhcloudseekho@gmail.com/data-engineering-with-databricks/jobs_lab_92/database.db
# | DA.paths.datasets:    dbfs:/mnt/dbacademy-datasets/data-engineering-with-databricks/v02
# | DA.paths.checkpoints: dbfs:/mnt/dbacademy-users/munirsheikhcloudseekho@gmail.com/data-engineering-with-databricks/jobs_lab_92/_checkpoints
#
# Setup completed (9 seconds)

# %% [markdown]
# <i18n value="1372d675-796a-4bbb-9d83-356d3b1b297e"/>
#
#
# # Exploring the Results of a DLT Pipeline
#
# Run the following cell to enumerate the output of your storage location:

# %%
files = dbutils.fs.ls(f"{DA.paths.working_dir}/storage")
display(files)
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# <command-4094000743659280> in <cell line: 1>()
# ----> 1 files = dbutils.fs.ls(f"{DA.paths.working_dir}/storage")
#       2 display(files)
#
# /databricks/python_shell/dbruntime/dbutils.py in f_with_exception_handling(*args, **kwargs)
#     360                     exc.__context__ = None
#     361                     exc.__cause__ = None
# --> 362                     raise exc
#     363
#     364             return f_with_exception_handling
#
# ExecutionError: An error occurred while calling o515.ls.
# : java.io.FileNotFoundException: /mnt/dbacademy-users/munirsheikhcloudseekho@gmail.com/data-engineering-with-databricks/jobs_lab_92/storage
# 	at com.databricks.backend.daemon.data.client.DbfsClient.send0(DbfsClient.scala:121)
# 	at com.databricks.backend.daemon.data.client.DbfsClient.sendIdempotent(DbfsClient.scala:69)
# ...

# %% [markdown]
# <i18n value="9a19b4f8-479b-4dfb-80a8-05e08cfd9eb0"/>
#
#
# The **system** directory captures events associated with the pipeline.

# %%
files = dbutils.fs.ls(f"{DA.paths.working_dir}/storage/system/events")
display(files)

# %% [markdown]
# <i18n value="da333edd-ee6d-4892-9da0-29f38d96e14f"/>
#
#
# These event logs are stored as a Delta table.
#
# Let's query the table.

# %%
# %sql
SELECT * FROM delta.`${da.paths.working_dir}/storage/system/events`

# %% [markdown]
# <i18n value="303e482b-e3cd-48eb-b9be-5357e07803aa"/>
#
#
# Let's view the contents of the *tables* directory.

# %%
files = dbutils.fs.ls(f"{DA.paths.working_dir}/storage/tables")
display(files)

# %% [markdown]
# <i18n value="6c5ffd14-74db-4ec2-8764-526da08840ab"/>
#
#
# Let's query the gold table.

# %%
# %sql
SELECT * FROM ${da.schema_name}.daily_patient_avg

# %%
DA.cleanup()
